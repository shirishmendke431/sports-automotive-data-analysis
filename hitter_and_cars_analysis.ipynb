# %%
import pandas  as  pd

# %%
df = pd.read_csv(r"C:\Users\admin\Downloads\hitters (1).csv")

# %% [markdown]
# # basic check

# %%
df.head()
# Out:
#                Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0     Andy Allanson    293    66      1    30   29     14      1     293
# 1        Alan Ashby    315    81      7    24   38     39     14    3449
# 2       Alvin Davis    479   130     18    66   72     76      3    1624
# 3      Andre Dawson    496   141     20    65   78     37     11    5628
# 4  Andres Galarraga    321    87     10    39   42     30      2     396
#
#    CHits  ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  Errors  \
# 0     66  ...     30    29      14       A        E     446       33      20
# 1    835  ...    321   414     375       N        W     632       43      10
# 2    457  ...    224   266     263       A        W     880       82      14
# 3   1575  ...    828   838     354       N        E     200       11       3
# 4    101  ...     48    46      33       N        E     805       40       4
#
#    Salary  NewLeague
# 0     NaN          A
# ...

# %%
df.columns
# Out:
# Index(['Name', 'AtBat', 'Hits', 'HmRun', 'Runs', 'RBI', 'Walks', 'Years',
#        'CAtBat', 'CHits', 'CHmRun', 'CRuns', 'CRBI', 'CWalks', 'League',
#        'Division', 'PutOuts', 'Assists', 'Errors', 'Salary', 'NewLeague'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Name          0
# AtBat         0
# Hits          0
# HmRun         0
# Runs          0
# RBI           0
# Walks         0
# Years         0
# CAtBat        0
# CHits         0
# CHmRun        0
# CRuns         0
# CRBI          0
# CWalks        0
# League        0
# Division      0
# PutOuts       0
# Assists       0
# Errors        0
# Salary       59
# NewLeague     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Hitters Dataset
# ------------------
# Find out no of missing values in each column





# -------------
# Cars Dataset
# -------------


# 1. Find out car having highest Mileage in city
# 2. Find out Models of cars which are having Price between 17 and 25
# 3. Find out top 7 most fuel economic cars for highway

# 5. Find out top 7 most fuel economic cars for city, show results in sorted manner based on Horsepower.

# %%
# ------------------
# Find out no of missing values in each column
df.isna().sum()
# Out:
# Name          0
# AtBat         0
# Hits          0
# HmRun         0
# Runs          0
# RBI           0
# Walks         0
# Years         0
# CAtBat        0
# CHits         0
# CHmRun        0
# CRuns         0
# CRBI          0
# CWalks        0
# League        0
# Division      0
# PutOuts       0
# Assists       0
# Errors        0
# Salary       59
# NewLeague     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'AtBat', 'Hits', 'HmRun', 'Runs', 'RBI', 'Walks', 'Years',
#        'CAtBat', 'CHits', 'CHmRun', 'CRuns', 'CRBI', 'CWalks', 'League',
#        'Division', 'PutOuts', 'Assists', 'Errors', 'Salary', 'NewLeague'],
#       dtype='object')

# %%
# Find of people who have batted for more than 400 matches
df.query('CAtBat>400')[['Name',  'CAtBat' ]]
df[df['CAtBat']>400][['Name',  'CAtBat' ]]
# Out:
#                 Name  CAtBat
# 1         Alan Ashby    3449
# 2        Alvin Davis    1624
# 3       Andre Dawson    5628
# 5    Alfredo Griffin    4408
# 7    Argenis Salazar     509
# ..               ...     ...
# 317     Willie McGee    2703
# 318  Willie Randolph    5511
# 319   Wayne Tolleson    1700
# 320    Willie Upshaw    3198
# 321    Willie Wilson    4908
#
# [284 rows x 2 columns]

# %%
# Find out the name of the player who has hit max home runs
df.sort_values(by  ='CHmRun' ,  ascending  = False)[['Name' , 'CHmRun']].head(1)
# Out:
#                Name  CHmRun
# 249  Reggie Jackson     548

# %%
df.CHmRun.max()
# Out:
# 548

# %%
df[df['CHmRun']==548]
# Out:
#                Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 249  Reggie Jackson    419   101     18    65   58     92     20    9528
#
#      CHits  ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  \
# 249   2510  ...   1509  1659    1342       A        W       0        0
#
#      Errors  Salary  NewLeague
# 249       0   487.5          A
#
# [1 rows x 21 columns]

# %%
# Find out league wise total number of players
df.League.value_counts()
df.groupby('League').Name.count()
# Out:
# League
# A    175
# N    147
# Name: Name, dtype: int64

# %%
# Find out division wise total amount of salary invested
df.groupby('Division').Salary.sum()
# Out:
# Division
# E    80531.006
# W    60417.501
# Name: Salary, dtype: float64

# %%
# Find out five most senior players.
df.sort_values('Years'  , ascending  = False).head(5)[['Name' ,  'Years']]
# Out:
#                Name  Years
# 236       Pete Rose     24
# 302      Tony Perez     23
# 121   Graig Nettles     20
# 249  Reggie Jackson     20
# 306     Ted Simmons     19

# %% [markdown]
# # Cars

# %%
df = pd.read_csv(r"C:\Users\admin\Downloads\Cars93 (2).csv")

# %%
df.head()
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
# 3   4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4   5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                 NaN  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
# 3           26                 NaN  ...          6    193        106     70
# 4           30         Driver only  ...          4    186        109     69
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')

# %%
# 1. Find out car having highest Mileage in city
df.sort_values(by  ='MPG.city' ,  ascending  = False).head(1)
df['MPG.city'].max()
df.query('`MPG.city`==46')
# Out:
#     id Manufacturer  Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo  Metro  Small        6.7    8.4       10.0        46
#
#     MPG.highway AirBags  ... Passengers Length  Wheelbase  Width  Turn.circle  \
# 38           50     NaN  ...          4    151         93     63           34
#
#     Rear.seat.room Luggage.room  Weight   Origin       Make
# 38            27.5         10.0    1695  non-USA  Geo Metro
#
# [1 rows x 28 columns]

# %%
 #2. Find out Models of cars which are having Price between 17 and 25
 df[df['Price'].between(17 ,25 )]
# Out:
#     id Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 6    7        Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8        Buick      Roadmaster    Large       22.6   23.7       24.9
# 17  18    Chevrolet         Caprice    Large       18.0   18.8       19.6
# 19  20     Chrylser        Concorde    Large       18.4   18.4       18.4
# 25  26        Dodge         Caravan      Van       13.6   19.0       24.4
# 29  30        Eagle          Vision    Large       17.5   19.3       21.2
# 35  36         Ford        Aerostar      Van       14.5   19.9       25.3
# 36  37         Ford          Taurus  Midsize       15.6   20.2       24.8
# 37  38         Ford  Crown_Victoria    Large       20.1   20.9       21.7
# 40  41        Honda         Prelude   Sporty       17.0   19.8       22.7
# 42  43        Honda          Accord  Compact       13.8   17.5       21.2
# 55  56        Mazda             MPV      Van       16.6   19.1       21.7
# ...

# %%
df.query('Price >= 17 & Price<=25')
# Out:
#     id Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 6    7        Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8        Buick      Roadmaster    Large       22.6   23.7       24.9
# 17  18    Chevrolet         Caprice    Large       18.0   18.8       19.6
# 19  20     Chrylser        Concorde    Large       18.4   18.4       18.4
# 25  26        Dodge         Caravan      Van       13.6   19.0       24.4
# 29  30        Eagle          Vision    Large       17.5   19.3       21.2
# 35  36         Ford        Aerostar      Van       14.5   19.9       25.3
# 36  37         Ford          Taurus  Midsize       15.6   20.2       24.8
# 37  38         Ford  Crown_Victoria    Large       20.1   20.9       21.7
# 40  41        Honda         Prelude   Sporty       17.0   19.8       22.7
# 42  43        Honda          Accord  Compact       13.8   17.5       21.2
# 55  56        Mazda             MPV      Van       16.6   19.1       21.7
# ...

# %%
# 3. Find out top 7 most fuel economic cars for highway
df.sort_values('MPG.highway' , ascending   = False).head(7)
# Out:
#     id Manufacturer   Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo   Metro  Small        6.7    8.4       10.0        46
# 41  42        Honda   Civic  Small        8.4   12.1       15.8        42
# 82  83       Suzuki   Swift  Small        7.3    8.6       10.0        39
# 72  73      Pontiac  LeMans  Small        8.2    9.0        9.9        31
# 78  79       Saturn      SL  Small        9.2   11.1       12.9        28
# 83  84       Toyota  Tercel  Small        7.8    9.8       11.8        32
# 79  80       Subaru   Justy  Small        7.3    8.4        9.5        33
#
#     MPG.highway      AirBags  ... Passengers Length  Wheelbase  Width  \
# 38           50          NaN  ...          4    151         93     63
# 41           46  Driver only  ...          4    173        103     67
# 82           43          NaN  ...          4    161         93     63
# 72           41          NaN  ...          4    177         99     66
# ...

# %%
# 5. Find out top 7 most fuel economic cars for city, show results in sorted manner based on Horsepower.

df.sort_values(by  ='MPG.city'  , ascending  =  False).head(7)[['Manufacturer',	'Model' , 'MPG.city' , 'Horsepower']].sort_values('Horsepower')
# Out:
#    Manufacturer    Model  MPG.city  Horsepower
# 38          Geo    Metro        46          55
# 30         Ford  Festiva        31          63
# 82       Suzuki    Swift        39          70
# 79       Subaru    Justy        33          73
# 72      Pontiac   LeMans        31          74
# 83       Toyota   Tercel        32          82
# 41        Honda    Civic        42         102

# %%
df.Origin.unique()
# Out:
# array(['non-USA', 'USA'], dtype=object)

# %%
df.AirBags.value_counts()
# Out:
# AirBags
# Driver only           42
# Driver & Passenger    14
# Name: count, dtype: int64

# %%
# 1. Find out Cars having mileage of more than 15 miles in city
df.query('`MPG.city`>15')[['Manufacturer' ,  'Model' , 'MPG.city']]
# Out:
#    Manufacturer    Model  MPG.city
# 0         Acura  Integra        25
# 1         Acura   Legend        18
# 2          Audi       90        20
# 3          Audi      100        19
# 4           BMW     535i        22
# ..          ...      ...       ...
# 88   Volkswagen  Eurovan        17
# 89   Volkswagen   Passat        21
# 90   Volkswagen  Corrado        18
# 91        Volvo      240        21
# 92        Volvo      850        20
#
# [91 rows x 3 columns]

# %%
# 2. Find out Cars with US based origin¶
df.query('Origin=="USA"')
# Out:
#     id Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 5    6        Buick         Century  Midsize       14.2   15.7       17.3
# 6    7        Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8        Buick      Roadmaster    Large       22.6   23.7       24.9
# 8    9        Buick         Riviera  Midsize       26.3   26.3       26.3
# 9   10     Cadillac         DeVille    Large       33.0   34.7       36.3
# 10  11     Cadillac         Seville  Midsize       37.5   40.1       42.7
# 11  12    Chevrolet        Cavalier  Compact        8.5   13.4       18.3
# 12  13    Chevrolet         Corsica  Compact       11.4   11.4       11.4
# 13  14    Chevrolet          Camaro   Sporty       13.4   15.1       16.8
# 14  15    Chevrolet          Lumina  Midsize       13.4   15.9       18.4
# 15  16    Chevrolet      Lumina_APV      Van       14.7   16.3       18.0
# 16  17    Chevrolet           Astro      Van       14.7   16.6       18.6
# ...

# %%
# 3. Find out Cars with no airbags and which are compact in type, from the output retrieve only Model, Mileage in city, Type, Airbags
df.query('AirBags=="None" & \
Type== "Compact"' )[['Model', 'MPG.city', 'Type', 'AirBags']]
# Out:
# Empty DataFrame
# Columns: [Model, MPG.city, Type, AirBags]
# Index: []

# %%
# 4. Find out cars with Mileage in city more than 15 which are compact in type.
df.query('`MPG.city`>15 \
 & Type== "Compact"' )\
  [['Model', 'MPG.city', 'Type', 'AirBags']]
# Out:
#        Model  MPG.city     Type             AirBags
# 2         90        20  Compact         Driver only
# 11  Cavalier        25  Compact                 NaN
# 12   Corsica        25  Compact         Driver only
# 20   LeBaron        23  Compact  Driver & Passenger
# 24    Spirit        22  Compact         Driver only
# 32     Tempo        22  Compact                 NaN
# 42    Accord        24  Compact  Driver & Passenger
# 54       626        26  Compact         Driver only
# 57      190E        20  Compact         Driver only
# 64    Altima        24  Compact         Driver only
# 67   Achieva        24  Compact                 NaN
# 73   Sunbird        23  Compact                 NaN
# 77       900        20  Compact         Driver only
# 81    Legacy        23  Compact         Driver only
# 89    Passat        21  Compact                 NaN
# 91       240        21  Compact         Driver only
